# %%
import pandas as pd

# %%
import numpy as np

# %%
import sklearn as sk

# %%
kar = pd.read_excel("pakistan_aqi_weather.xlsx", sheet_name = "Karachi")

# %%
lah = pd.read_excel("pakistan_aqi_weather.xlsx", sheet_name = "Lahore")

# %%
kar.head()
# Out:
#                time  pm10  pm2_5  carbon_monoxide  nitrogen_dioxide  \
# 0  2022-01-01T00:00   NaN    NaN              NaN               NaN
# 1  2022-01-01T01:00   NaN    NaN              NaN               NaN
# 2  2022-01-01T02:00   NaN    NaN              NaN               NaN
# 3  2022-01-01T03:00   NaN    NaN              NaN               NaN
# 4  2022-01-01T04:00   NaN    NaN              NaN               NaN
#
#    sulphur_dioxide  ozone  aerosol_optical_depth  dust  uv_index  ...  \
# 0              NaN    NaN                    NaN   NaN       NaN  ...
# 1              NaN    NaN                    NaN   NaN       NaN  ...
# 2              NaN    NaN                    NaN   NaN       NaN  ...
# 3              NaN    NaN                    NaN   NaN       NaN  ...
# 4              NaN    NaN                    NaN   NaN       NaN  ...
#
#    cloud_cover_low  cloud_cover_mid  cloud_cover_high  wind_speed_10m  \
# ...

# %%
lah.head()
# Out:
#                time  pm10  pm2_5  carbon_monoxide  nitrogen_dioxide  \
# 0  2022-01-01T00:00   NaN    NaN              NaN               NaN
# 1  2022-01-01T01:00   NaN    NaN              NaN               NaN
# 2  2022-01-01T02:00   NaN    NaN              NaN               NaN
# 3  2022-01-01T03:00   NaN    NaN              NaN               NaN
# 4  2022-01-01T04:00   NaN    NaN              NaN               NaN
#
#    sulphur_dioxide  ozone  aerosol_optical_depth  dust  uv_index  ...  \
# 0              NaN    NaN                    NaN   NaN       NaN  ...
# 1              NaN    NaN                    NaN   NaN       NaN  ...
# 2              NaN    NaN                    NaN   NaN       NaN  ...
# 3              NaN    NaN                    NaN   NaN       NaN  ...
# 4              NaN    NaN                    NaN   NaN       NaN  ...
#
#    cloud_cover_low  cloud_cover_mid  cloud_cover_high  wind_speed_10m  \
# ...

# %%
kar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38376 entries, 0 to 38375
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   time                   38376 non-null  object
#  1   pm10                   33211 non-null  float64
#  2   pm2_5                  33211 non-null  float64
#  3   carbon_monoxide        33211 non-null  float64
#  4   nitrogen_dioxide       33211 non-null  float64
#  5   sulphur_dioxide        33211 non-null  float64
#  6   ozone                  33211 non-null  float64
#  7   aerosol_optical_depth  33211 non-null  float64
#  8   dust                   33211 non-null  float64
#  9   uv_index               33211 non-null  float64
#  10  uv_index_clear_sky     33211 non-null  float64
#  11  ammonia                0 non-null      float64
#  12  temperature_2m         38376 non-null  float64
#  13  relative_humidity_2m   38376 non-null  int64
# ...

# %%
kar.drop(columns = ["ammonia"], inplace = True)

# %%
kar.dropna(subset = ["pm10","pm2_5","carbon_monoxide", "nitrogen_dioxide", "sulphur_dioxide", "ozone","aerosol_optical_depth", "dust", "uv_index", "uv_index_clear_sky"], inplace = True)

# %%
kar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33211 entries, 5165 to 38375
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   time                   33211 non-null  object
#  1   pm10                   33211 non-null  float64
#  2   pm2_5                  33211 non-null  float64
#  3   carbon_monoxide        33211 non-null  float64
#  4   nitrogen_dioxide       33211 non-null  float64
#  5   sulphur_dioxide        33211 non-null  float64
#  6   ozone                  33211 non-null  float64
#  7   aerosol_optical_depth  33211 non-null  float64
#  8   dust                   33211 non-null  float64
#  9   uv_index               33211 non-null  float64
#  10  uv_index_clear_sky     33211 non-null  float64
#  11  temperature_2m         33211 non-null  float64
#  12  relative_humidity_2m   33211 non-null  int64
#  13  dew_point_2m           33211 non-null  float64
# ...

# %%
kar["time"] = pd.to_datetime(kar["time"])

# %%
 #### For LAHORE

# %%
lah.drop(columns = ["ammonia"], inplace = True)

# %%
lah.dropna(subset = ["pm10","pm2_5","carbon_monoxide", "nitrogen_dioxide", "sulphur_dioxide", "ozone","aerosol_optical_depth", "dust", "uv_index", "uv_index_clear_sky"], inplace = True)

# %%
lah["time"] = pd.to_datetime(lah["time"])

# %%
output_file = "pakistan_aqi_weather.xlsx"

with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
    kar.to_excel(writer, sheet_name="Karachi", index=False)
    lah.to_excel(writer, sheet_name="Lahore", index=False)
